# %% [markdown]
# # Trabajo Final de Estadística.
# ## Análisis exploratorio de datos.
# ## Tema:
# Análisis sobre el cancer de pulmón en una muestra de la población.
#
# # Integrantes:
# - Jorge Alejandro Echevarría Brunet.
# - Rodrigo Mederos González.
# - Amalia Beatriz Valiente Hinojosa.

# %% [markdown]
# ## ¿Qué es el cancer de pulmón?
# El cáncer de pulmón es un tipo de tumor maligno que se origina en los pulmones, generalmente asociado al tabaquismo, pero también puede ser causado por factores genéticos o ambientales. Existen dos tipos principales: el cáncer de pulmón de células no pequeñas y el de células pequeñas.

# %% [markdown]
# # Síntomas del cáncer de pulmón:
# 1. Tos persistente o que empeora con el tiempo.
# 2. Dolor en el pecho que se intensifica al respirar profundamente, toser o reír.
# 3. Dificultad para respirar (disnea).
# 4. Sibilancias o voz ronca.
# 5. Pérdida de peso sin causa aparente.
# 6. Fatiga constante o debilidad.
# 7. Infecciones pulmonares recurrentes (bronquitis o neumonía).
# 8. Tos con sangre (hemoptisis)

# %% [markdown]
# # Indicadores del cáncer de pulmón para personas no médicas
# 1. Tos persistente o que empeora con el tiempo.
# 2. Dificultad para respirar o sensación de falta de aire.
# 3. Dolor en el pecho al respirar, toser o reír.
# 4. Tos con sangre o esputo con color anormal.
# 5. Ronquera o cambios en la voz sin causa aparente.
# 6. Pérdida de peso inexplicada.
# 7. Cansancio extremo o debilidad constante.
# 8. Infecciones pulmonares frecuentes (bronquitis o neumonía repetidas).
# 9. Hinchazón en la cara o el cuello.
# 10. Dolor en los huesos o en otras partes del cuerpo sin explicación.

# %% [markdown]
# Se tomó una muestra de 309 personas para llevar a cabo un análisis estadístico sobre los factores asociados al cáncer de pulmón. A partir de esta muestra, se realizaron pruebas de hipótesis, modelos de regresión y otros estudios estadísticos con el objetivo de identificar y evaluar los factores de riesgo asociados al cáncer de pulmón, proporcionando evidencia cuantitativa sobre su impacto en la enfermedad.

# %% [markdown]
# # Variables:
# - **GENDER**: Género del paciente (Masculino/Femenino).
# - **AGE**: Edad del paciente.
# - **SMOKING**: Indica si el paciente fuma (Sí/No).
# - **YELLOW_FINGERS**: Si el paciente tiene dedos amarillos (asociado con el tabaquismo).
# - **ANXIETY**: Si el paciente sufre de ansiedad.
# - **PEER_PRESSURE**: Influencia de la presión social en el consumo de tabaco.
# - **CHRONIC DISEASE**: Si el paciente tiene alguna enfermedad crónica.
# - **FATIGUE**: Si el paciente sufre de fatiga.
# - **ALLERGY**: Presencia de alergias.
# - **WHEEZING**: Si el paciente tiene respiración sibilante.
# - **ALCOHOL CONSUMING**: Si el paciente consume alcohol.
# - **COUGHING**: Si el paciente presenta tos frecuente.
# - **SHORTNESS OF BREATH**: Si el paciente experimenta dificultad para respirar.
# - **SWALLOWING DIFFICULTY**: Si el paciente tiene dificultad para tragar.
# - **CHEST PAIN**: Si el paciente sufre de dolor en el pecho.
# - **LUNG_CANCER**: Diagnóstico de cáncer de pulmón (Sí/No).

# %%
#cargando librerias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from statsmodels.stats.proportion import proportions_ztest
import statsmodels.api as sm

# %%
file_path = "survey lung cancer.csv"
data = pd.read_csv(file_path)

# %% [markdown]
# # Información sobre el Dataset:

# %%
print(f"Forma del Dataset : {data.shape}")
print(f"\nVista del Dataset :")
data.head().style.set_properties(**{"background-color": "#2a9d8f","color":"white","border": "1.5px  solid black"})
# Out:
# Forma del Dataset : (309, 16)
#
# Vista del Dataset :
# <style type="text/css">
# #T_3d254_row0_col0, #T_3d254_row0_col1, #T_3d254_row0_col2, #T_3d254_row0_col3, #T_3d254_row0_col4, #T_3d254_row0_col5, #T_3d254_row0_col6, #T_3d254_row0_col7, #T_3d254_row0_col8, #T_3d254_row0_col9, #T_3d254_row0_col10, #T_3d254_row0_col11, #T_3d254_row0_col12, #T_3d254_row0_col13, #T_3d254_row0_col14, #T_3d254_row0_col15, #T_3d254_row1_col0, #T_3d254_row1_col1, #T_3d254_row1_col2, #T_3d254_row1_col3, #T_3d254_row1_col4, #T_3d254_row1_col5, #T_3d254_row1_col6, #T_3d254_row1_col7, #T_3d254_row1_col8, #T_3d254_row1_col9, #T_3d254_row1_col10, #T_3d254_row1_col11, #T_3d254_row1_col12, #T_3d254_row1_col13, #T_3d254_row1_col14, #T_3d254_row1_col15, #T_3d254_row2_col0, #T_3d254_row2_col1, #T_3d254_row2_col2, #T_3d254_row2_col3, #T_3d254_row2_col4, #T_3d254_row2_col5, #T_3d254_row2_col6, #T_3d254_row2_col7, #T_3d254_row2_col8, #T_3d254_row2_col9, #T_3d254_row2_col10, #T_3d254_row2_col11, #T_3d254_row2_col12, #T_3d254_row2_col13, #T_3d254_row2_col14, #T_3d254_row2_col15, #T_3d254_row3_col0, #T_3d254_row3_col1, #T_3d254_row3_col2, #T_3d254_row3_col3, #T_3d254_row3_col4, #T_3d254_row3_col5, #T_3d254_row3_col6, #T_3d254_row3_col7, #T_3d254_row3_col8, #T_3d254_row3_col9, #T_3d254_row3_col10, #T_3d254_row3_col11, #T_3d254_row3_col12, #T_3d254_row3_col13, #T_3d254_row3_col14, #T_3d254_row3_col15, #T_3d254_row4_col0, #T_3d254_row4_col1, #T_3d254_row4_col2, #T_3d254_row4_col3, #T_3d254_row4_col4, #T_3d254_row4_col5, #T_3d254_row4_col6, #T_3d254_row4_col7, #T_3d254_row4_col8, #T_3d254_row4_col9, #T_3d254_row4_col10, #T_3d254_row4_col11, #T_3d254_row4_col12, #T_3d254_row4_col13, #T_3d254_row4_col14, #T_3d254_row4_col15 {
#   background-color: #2a9d8f;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_3d254">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3d254_level0_col0" class="col_heading level0 col0" >GENDER</th>
#       <th id="T_3d254_level0_col1" class="col_heading level0 col1" >AGE</th>
#       <th id="T_3d254_level0_col2" class="col_heading level0 col2" >SMOKING</th>
#       <th id="T_3d254_level0_col3" class="col_heading level0 col3" >YELLOW_FINGERS</th>
#       <th id="T_3d254_level0_col4" class="col_heading level0 col4" >ANXIETY</th>
#       <th id="T_3d254_level0_col5" class="col_heading level0 col5" >PEER_PRESSURE</th>
#       <th id="T_3d254_level0_col6" class="col_heading level0 col6" >CHRONIC DISEASE</th>
#       <th id="T_3d254_level0_col7" class="col_heading level0 col7" >FATIGUE </th>
#       <th id="T_3d254_level0_col8" class="col_heading level0 col8" >ALLERGY </th>
#       <th id="T_3d254_level0_col9" class="col_heading level0 col9" >WHEEZING</th>
#       <th id="T_3d254_level0_col10" class="col_heading level0 col10" >ALCOHOL CONSUMING</th>
#       <th id="T_3d254_level0_col11" class="col_heading level0 col11" >COUGHING</th>
#       <th id="T_3d254_level0_col12" class="col_heading level0 col12" >SHORTNESS OF BREATH</th>
#       <th id="T_3d254_level0_col13" class="col_heading level0 col13" >SWALLOWING DIFFICULTY</th>
#       <th id="T_3d254_level0_col14" class="col_heading level0 col14" >CHEST PAIN</th>
#       <th id="T_3d254_level0_col15" class="col_heading level0 col15" >LUNG_CANCER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d254_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3d254_row0_col0" class="data row0 col0" >M</td>
#       <td id="T_3d254_row0_col1" class="data row0 col1" >69</td>
#       <td id="T_3d254_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_3d254_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_3d254_row0_col4" class="data row0 col4" >2</td>
#       <td id="T_3d254_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_3d254_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_3d254_row0_col7" class="data row0 col7" >2</td>
#       <td id="T_3d254_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_3d254_row0_col9" class="data row0 col9" >2</td>
#       <td id="T_3d254_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_3d254_row0_col11" class="data row0 col11" >2</td>
#       <td id="T_3d254_row0_col12" class="data row0 col12" >2</td>
#       <td id="T_3d254_row0_col13" class="data row0 col13" >2</td>
#       <td id="T_3d254_row0_col14" class="data row0 col14" >2</td>
#       <td id="T_3d254_row0_col15" class="data row0 col15" >YES</td>
#     </tr>
#     <tr>
#       <th id="T_3d254_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3d254_row1_col0" class="data row1 col0" >M</td>
#       <td id="T_3d254_row1_col1" class="data row1 col1" >74</td>
#       <td id="T_3d254_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_3d254_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_3d254_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_3d254_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_3d254_row1_col6" class="data row1 col6" >2</td>
#       <td id="T_3d254_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_3d254_row1_col8" class="data row1 col8" >2</td>
#       <td id="T_3d254_row1_col9" class="data row1 col9" >1</td>
#       <td id="T_3d254_row1_col10" class="data row1 col10" >1</td>
#       <td id="T_3d254_row1_col11" class="data row1 col11" >1</td>
#       <td id="T_3d254_row1_col12" class="data row1 col12" >2</td>
#       <td id="T_3d254_row1_col13" class="data row1 col13" >2</td>
#       <td id="T_3d254_row1_col14" class="data row1 col14" >2</td>
#       <td id="T_3d254_row1_col15" class="data row1 col15" >YES</td>
#     </tr>
#     <tr>
#       <th id="T_3d254_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3d254_row2_col0" class="data row2 col0" >F</td>
#       <td id="T_3d254_row2_col1" class="data row2 col1" >59</td>
#       <td id="T_3d254_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_3d254_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_3d254_row2_col4" class="data row2 col4" >1</td>
#       <td id="T_3d254_row2_col5" class="data row2 col5" >2</td>
#       <td id="T_3d254_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_3d254_row2_col7" class="data row2 col7" >2</td>
#       <td id="T_3d254_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_3d254_row2_col9" class="data row2 col9" >2</td>
#       <td id="T_3d254_row2_col10" class="data row2 col10" >1</td>
#       <td id="T_3d254_row2_col11" class="data row2 col11" >2</td>
#       <td id="T_3d254_row2_col12" class="data row2 col12" >2</td>
#       <td id="T_3d254_row2_col13" class="data row2 col13" >1</td>
#       <td id="T_3d254_row2_col14" class="data row2 col14" >2</td>
#       <td id="T_3d254_row2_col15" class="data row2 col15" >NO</td>
#     </tr>
#     <tr>
#       <th id="T_3d254_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3d254_row3_col0" class="data row3 col0" >M</td>
#       <td id="T_3d254_row3_col1" class="data row3 col1" >63</td>
#       <td id="T_3d254_row3_col2" class="data row3 col2" >2</td>
#       <td id="T_3d254_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_3d254_row3_col4" class="data row3 col4" >2</td>
#       <td id="T_3d254_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_3d254_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_3d254_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_3d254_row3_col8" class="data row3 col8" >1</td>
#       <td id="T_3d254_row3_col9" class="data row3 col9" >1</td>
#       <td id="T_3d254_row3_col10" class="data row3 col10" >2</td>
#       <td id="T_3d254_row3_col11" class="data row3 col11" >1</td>
#       <td id="T_3d254_row3_col12" class="data row3 col12" >1</td>
#       <td id="T_3d254_row3_col13" class="data row3 col13" >2</td>
#       <td id="T_3d254_row3_col14" class="data row3 col14" >2</td>
#       <td id="T_3d254_row3_col15" class="data row3 col15" >NO</td>
#     </tr>
#     <tr>
#       <th id="T_3d254_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3d254_row4_col0" class="data row4 col0" >F</td>
#       <td id="T_3d254_row4_col1" class="data row4 col1" >63</td>
#       <td id="T_3d254_row4_col

# %%
print(f"Información acerca del Dataset :\n")
print(data.info())
# Out:
# Información acerca del Dataset :
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    object
#  1   AGE                    309 non-null    int64
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        309 non-null    int64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               309 non-null    int64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               309 non-null    int64
#  12  SHORTNESS OF BREATH    309 non-null    int64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
#  14  CHEST PAIN             309 non-null    int64
#  15  LUNG_CANCER            309 non-null    object
# dtypes: int64(14), object(2)
# memory usage: 38.8+ KB
# None

# %%
print(f"Resumen del Dataset :")
data.describe().T.style.set_properties(**{"background-color": "#2a9d8f","color":"white","border": "1.5px  solid black"})
# Out:
# Resumen del Dataset :
# <style type="text/css">
# #T_3689a_row0_col0, #T_3689a_row0_col1, #T_3689a_row0_col2, #T_3689a_row0_col3, #T_3689a_row0_col4, #T_3689a_row0_col5, #T_3689a_row0_col6, #T_3689a_row0_col7, #T_3689a_row1_col0, #T_3689a_row1_col1, #T_3689a_row1_col2, #T_3689a_row1_col3, #T_3689a_row1_col4, #T_3689a_row1_col5, #T_3689a_row1_col6, #T_3689a_row1_col7, #T_3689a_row2_col0, #T_3689a_row2_col1, #T_3689a_row2_col2, #T_3689a_row2_col3, #T_3689a_row2_col4, #T_3689a_row2_col5, #T_3689a_row2_col6, #T_3689a_row2_col7, #T_3689a_row3_col0, #T_3689a_row3_col1, #T_3689a_row3_col2, #T_3689a_row3_col3, #T_3689a_row3_col4, #T_3689a_row3_col5, #T_3689a_row3_col6, #T_3689a_row3_col7, #T_3689a_row4_col0, #T_3689a_row4_col1, #T_3689a_row4_col2, #T_3689a_row4_col3, #T_3689a_row4_col4, #T_3689a_row4_col5, #T_3689a_row4_col6, #T_3689a_row4_col7, #T_3689a_row5_col0, #T_3689a_row5_col1, #T_3689a_row5_col2, #T_3689a_row5_col3, #T_3689a_row5_col4, #T_3689a_row5_col5, #T_3689a_row5_col6, #T_3689a_row5_col7, #T_3689a_row6_col0, #T_3689a_row6_col1, #T_3689a_row6_col2, #T_3689a_row6_col3, #T_3689a_row6_col4, #T_3689a_row6_col5, #T_3689a_row6_col6, #T_3689a_row6_col7, #T_3689a_row7_col0, #T_3689a_row7_col1, #T_3689a_row7_col2, #T_3689a_row7_col3, #T_3689a_row7_col4, #T_3689a_row7_col5, #T_3689a_row7_col6, #T_3689a_row7_col7, #T_3689a_row8_col0, #T_3689a_row8_col1, #T_3689a_row8_col2, #T_3689a_row8_col3, #T_3689a_row8_col4, #T_3689a_row8_col5, #T_3689a_row8_col6, #T_3689a_row8_col7, #T_3689a_row9_col0, #T_3689a_row9_col1, #T_3689a_row9_col2, #T_3689a_row9_col3, #T_3689a_row9_col4, #T_3689a_row9_col5, #T_3689a_row9_col6, #T_3689a_row9_col7, #T_3689a_row10_col0, #T_3689a_row10_col1, #T_3689a_row10_col2, #T_3689a_row10_col3, #T_3689a_row10_col4, #T_3689a_row10_col5, #T_3689a_row10_col6, #T_3689a_row10_col7, #T_3689a_row11_col0, #T_3689a_row11_col1, #T_3689a_row11_col2, #T_3689a_row11_col3, #T_3689a_row11_col4, #T_3689a_row11_col5, #T_3689a_row11_col6, #T_3689a_row11_col7, #T_3689a_row12_col0, #T_3689a_row12_col1, #T_3689a_row12_col2, #T_3689a_row12_col3, #T_3689a_row12_col4, #T_3689a_row12_col5, #T_3689a_row12_col6, #T_3689a_row12_col7, #T_3689a_row13_col0, #T_3689a_row13_col1, #T_3689a_row13_col2, #T_3689a_row13_col3, #T_3689a_row13_col4, #T_3689a_row13_col5, #T_3689a_row13_col6, #T_3689a_row13_col7 {
#   background-color: #2a9d8f;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_3689a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3689a_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_3689a_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_3689a_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_3689a_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_3689a_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_3689a_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_3689a_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_3689a_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3689a_level0_row0" class="row_heading level0 row0" >AGE</th>
#       <td id="T_3689a_row0_col0" class="data row0 col0" >309.000000</td>
#       <td id="T_3689a_row0_col1" class="data row0 col1" >62.673139</td>
#       <td id="T_3689a_row0_col2" class="data row0 col2" >8.210301</td>
#       <td id="T_3689a_row0_col3" class="data row0 col3" >21.000000</td>
#       <td id="T_3689a_row0_col4" class="data row0 col4" >57.000000</td>
#       <td id="T_3689a_row0_col5" class="data row0 col5" >62.000000</td>
#       <td id="T_3689a_row0_col6" class="data row0 col6" >69.000000</td>
#       <td id="T_3689a_row0_col7" class="data row0 col7" >87.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3689a_level0_row1" class="row_heading level0 row1" >SMOKING</th>
#       <td id="T_3689a_row1_col0" class="data row1 col0" >309.000000</td>
#       <td id="T_3689a_row1_col1" class="data row1 col1" >1.563107</td>
#       <td id="T_3689a_row1_col2" class="data row1 col2" >0.496806</td>
#       <td id="T_3689a_row1_col3" class="data row1 col3" >1.000000</td>
#       <td id="T_3689a_row1_col4" class="data row1 col4" >1.000000</td>
#       <td id="T_3689a_row1_col5" class="data row1 col5" >2.000000</td>
#       <td id="T_3689a_row1_col6" class="data row1 col6" >2.000000</td>
#       <td id="T_3689a_row1_col7" class="data row1 col7" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3689a_level0_row2" class="row_heading level0 row2" >YELLOW_FINGERS</th>
#       <td id="T_3689a_row2_col0" class="data row2 col0" >309.000000</td>
#       <td id="T_3689a_row2_col1" class="data row2 col1" >1.569579</td>
#       <td id="T_3689a_row2_col2" class="data row2 col2" >0.495938</td>
#       <td id="T_3689a_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_3689a_row2_col4" class="data row2 col4" >1.000000</td>
#       <td id="T_3689a_row2_col5" class="data row2 col5" >2.000000</td>
#       <td id="T_3689a_row2_col6" class="data row2 col6" >2.000000</td>
#       <td id="T_3689a_row2_col7" class="data row2 col7" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3689a_level0_row3" class="row_heading level0 row3" >ANXIETY</th>
#       <td id="T_3689a_row3_col0" class="data row3 col0" >309.000000</td>
#       <td id="T_3689a_row3_col1" class="data row3 col1" >1.498382</td>
#       <td id="T_3689a_row3_col2" class="data row3 col2" >0.500808</td>
#       <td id="T_3689a_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_3689a_row3_col4" class="data row3 col4" >1.000000</td>
#       <td id="T_3689a_row3_col5" class="data row3 col5" >1.000000</td>
#       <td id="T_3689a_row3_col6" class="data row3 col6" >2.000000</td>
#       <td id="T_3689a_row3_col7" class="data row3 col7" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3689a_level0_row4" class="row_heading level0 row4" >PEER_PRESSURE</th>
#       <td id="T_3689a_row4_col0" class="data row4 col0" >309.000000</td>
#       <td id="T_3689a_row4_col1" class="data row4 col1" >1.501618</td>
#       <td id="T_3689a_row4_col2" class="data row4 col2" >0.500808</td>
#       <td id="T_3689a_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_3689a_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_3689a_row4_col5" class="data row4 col5" >2.000000</td>
#       <td id="T_3689a_row4_col6" class="data row4 col6" >2.000000</td>
#       <td id="T_3689a_row4_col7" class="data row4 col7" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3689a_level0_row5" class="row_heading level0 row5" >CHRONIC DISEASE</th>
#       <td id="T_3689a_row5_col0" class="data row5 col0" >309.000000</td>
#       <td id="T_3689a_row5_col1" class="data row5 col1" >1.504854</td>
#       <td id="T_3689a_row5_col2" class="data row5 col2" >0.500787</td>
#       <td id="T_3689a_row5_col3" class="data row5 col3" >1.000000</td>
#       <td id="T_3689a_row5_col4" class="data row5 col4" >1.000000</td>
#       <td id="T_3689a_row5_col5" class="data row5 col5" >2.000000</td>
#       <td id="T_3689a_row5_col6" class="data row5 col6" >2.000000</td>
#       <td id="T_3689a_row5_col7" class="data row5 col7" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3689a_level0_row6" class="row_heading level0 row6" >FATIGUE </th>
#       <td id="T_3689a_row6_col0" class="data row6 col0" >309.000000</td>
#       <td id="T_3689a_row6_col1" class="data row6 col1" >1.673139</td>
#       <td id="T_3689a_row6_col2" class="data row6 col2" >0.469827</td>
#       <td id="T_3689a_row6_col3" class="data row6 col3" >1.000000</td>
#       <td id="T_3689a_row6_col4" class="data row6 col4" >1.000000</td>
#       <td id="T_3689a_row6_col5" class="data row6 col5" >2.000000</td>
#       <td id="T_3689a_row6_col6" class="data row6 col6" >2.000000</td>
#       <td id="T_3689a_row6_col7" class="data row6 col7" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3689a_level0_row7" class="row_heading level0 row7" >ALLERGY </th>
#       <td id="T_3689a_row7_col0" class="data row7 col0" >309.000000</td>

# %%
data.describe(include=object).T.style.set_properties(**{"background-color": "#2a9d8f","color":"white","border": "1.5px  solid black"})
# Out:
# <style type="text/css">
# #T_07760_row0_col0, #T_07760_row0_col1, #T_07760_row0_col2, #T_07760_row0_col3, #T_07760_row1_col0, #T_07760_row1_col1, #T_07760_row1_col2, #T_07760_row1_col3 {
#   background-color: #2a9d8f;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_07760">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_07760_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_07760_level0_col1" class="col_heading level0 col1" >unique</th>
#       <th id="T_07760_level0_col2" class="col_heading level0 col2" >top</th>
#       <th id="T_07760_level0_col3" class="col_heading level0 col3" >freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07760_level0_row0" class="row_heading level0 row0" >GENDER</th>
#       <td id="T_07760_row0_col0" class="data row0 col0" >309</td>
#       <td id="T_07760_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_07760_row0_col2" class="data row0 col2" >M</td>
#       <td id="T_07760_row0_col3" class="data row0 col3" >162</td>
#     </tr>
#     <tr>
#       <th id="T_07760_level0_row1" class="row_heading level0 row1" >LUNG_CANCER</th>
#       <td id="T_07760_row1_col0" class="data row1 col0" >309</td>
#       <td id="T_07760_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_07760_row1_col2" class="data row1 col2" >YES</td>
#       <td id="T_07760_row1_col3" class="data row1 col3" >270</td>
#     </tr>
#   </tbody>
# </table>

# %%
data.describe(include=object).T.style.set_properties(**{"background-color": "#2a9d8f","color":"white","border": "1.5px  solid black"})
# Out:
# <style type="text/css">
# #T_d25b4_row0_col0, #T_d25b4_row0_col1, #T_d25b4_row0_col2, #T_d25b4_row0_col3, #T_d25b4_row1_col0, #T_d25b4_row1_col1, #T_d25b4_row1_col2, #T_d25b4_row1_col3 {
#   background-color: #2a9d8f;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_d25b4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d25b4_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_d25b4_level0_col1" class="col_heading level0 col1" >unique</th>
#       <th id="T_d25b4_level0_col2" class="col_heading level0 col2" >top</th>
#       <th id="T_d25b4_level0_col3" class="col_heading level0 col3" >freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d25b4_level0_row0" class="row_heading level0 row0" >GENDER</th>
#       <td id="T_d25b4_row0_col0" class="data row0 col0" >309</td>
#       <td id="T_d25b4_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_d25b4_row0_col2" class="data row0 col2" >M</td>
#       <td id="T_d25b4_row0_col3" class="data row0 col3" >162</td>
#     </tr>
#     <tr>
#       <th id="T_d25b4_level0_row1" class="row_heading level0 row1" >LUNG_CANCER</th>
#       <td id="T_d25b4_row1_col0" class="data row1 col0" >309</td>
#       <td id="T_d25b4_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_d25b4_row1_col2" class="data row1 col2" >YES</td>
#       <td id="T_d25b4_row1_col3" class="data row1 col3" >270</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Aquí podemos ver que no existe un valor nulo en este conjunto de datos. Comprobemos si existe alguna entrada duplicada en este conjunto de datos. Si existe, los eliminaremos del conjunto de datos. Después de eso, inicializaremos el estilo de visualización y la paleta personalizada para la visualización.

# %%
dup = data[data.duplicated()].shape[0]
print(f"Hay {dup} datos duplicados {data.shape[0]} en el conjunto de datos.")

data.drop_duplicates(keep='first',inplace=True)
print(f"\nDespués de eliminar los duplicados hay {data.shape[0]} datos en el conjunto.")
# Out:
# Hay 33 datos duplicados 309 en el conjunto de datos.
#
# Después de eliminar los duplicados hay 276 datos en el conjunto.

# %% [markdown]
# Reemplacemos todos los valores numéricos por valores categóricos para una visualización mejor y más eficiente. Todos los 2 y 1 serán reemplazados por "SÍ" y "NO" en consecuencia. Y reemplace "M" y "F" por "Male" y "Female" en consecuencia en la columna "GENDER".

# %%
data_temp = data.copy()
data_temp["GENDER"] = data_temp["GENDER"].replace({"M" : "Male" , "F" : "Female"})

for column in data_temp.columns:
    data_temp[column] = data_temp[column].replace({2: "Yes" , 1 : "No"})

data_temp.head().style.set_properties(**{"background-color": "#2a9d8f","color":"white","border": "1.5px  solid black"})
# Out:
# <style type="text/css">
# #T_d5101_row0_col0, #T_d5101_row0_col1, #T_d5101_row0_col2, #T_d5101_row0_col3, #T_d5101_row0_col4, #T_d5101_row0_col5, #T_d5101_row0_col6, #T_d5101_row0_col7, #T_d5101_row0_col8, #T_d5101_row0_col9, #T_d5101_row0_col10, #T_d5101_row0_col11, #T_d5101_row0_col12, #T_d5101_row0_col13, #T_d5101_row0_col14, #T_d5101_row0_col15, #T_d5101_row1_col0, #T_d5101_row1_col1, #T_d5101_row1_col2, #T_d5101_row1_col3, #T_d5101_row1_col4, #T_d5101_row1_col5, #T_d5101_row1_col6, #T_d5101_row1_col7, #T_d5101_row1_col8, #T_d5101_row1_col9, #T_d5101_row1_col10, #T_d5101_row1_col11, #T_d5101_row1_col12, #T_d5101_row1_col13, #T_d5101_row1_col14, #T_d5101_row1_col15, #T_d5101_row2_col0, #T_d5101_row2_col1, #T_d5101_row2_col2, #T_d5101_row2_col3, #T_d5101_row2_col4, #T_d5101_row2_col5, #T_d5101_row2_col6, #T_d5101_row2_col7, #T_d5101_row2_col8, #T_d5101_row2_col9, #T_d5101_row2_col10, #T_d5101_row2_col11, #T_d5101_row2_col12, #T_d5101_row2_col13, #T_d5101_row2_col14, #T_d5101_row2_col15, #T_d5101_row3_col0, #T_d5101_row3_col1, #T_d5101_row3_col2, #T_d5101_row3_col3, #T_d5101_row3_col4, #T_d5101_row3_col5, #T_d5101_row3_col6, #T_d5101_row3_col7, #T_d5101_row3_col8, #T_d5101_row3_col9, #T_d5101_row3_col10, #T_d5101_row3_col11, #T_d5101_row3_col12, #T_d5101_row3_col13, #T_d5101_row3_col14, #T_d5101_row3_col15, #T_d5101_row4_col0, #T_d5101_row4_col1, #T_d5101_row4_col2, #T_d5101_row4_col3, #T_d5101_row4_col4, #T_d5101_row4_col5, #T_d5101_row4_col6, #T_d5101_row4_col7, #T_d5101_row4_col8, #T_d5101_row4_col9, #T_d5101_row4_col10, #T_d5101_row4_col11, #T_d5101_row4_col12, #T_d5101_row4_col13, #T_d5101_row4_col14, #T_d5101_row4_col15 {
#   background-color: #2a9d8f;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_d5101">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5101_level0_col0" class="col_heading level0 col0" >GENDER</th>
#       <th id="T_d5101_level0_col1" class="col_heading level0 col1" >AGE</th>
#       <th id="T_d5101_level0_col2" class="col_heading level0 col2" >SMOKING</th>
#       <th id="T_d5101_level0_col3" class="col_heading level0 col3" >YELLOW_FINGERS</th>
#       <th id="T_d5101_level0_col4" class="col_heading level0 col4" >ANXIETY</th>
#       <th id="T_d5101_level0_col5" class="col_heading level0 col5" >PEER_PRESSURE</th>
#       <th id="T_d5101_level0_col6" class="col_heading level0 col6" >CHRONIC DISEASE</th>
#       <th id="T_d5101_level0_col7" class="col_heading level0 col7" >FATIGUE </th>
#       <th id="T_d5101_level0_col8" class="col_heading level0 col8" >ALLERGY </th>
#       <th id="T_d5101_level0_col9" class="col_heading level0 col9" >WHEEZING</th>
#       <th id="T_d5101_level0_col10" class="col_heading level0 col10" >ALCOHOL CONSUMING</th>
#       <th id="T_d5101_level0_col11" class="col_heading level0 col11" >COUGHING</th>
#       <th id="T_d5101_level0_col12" class="col_heading level0 col12" >SHORTNESS OF BREATH</th>
#       <th id="T_d5101_level0_col13" class="col_heading level0 col13" >SWALLOWING DIFFICULTY</th>
#       <th id="T_d5101_level0_col14" class="col_heading level0 col14" >CHEST PAIN</th>
#       <th id="T_d5101_level0_col15" class="col_heading level0 col15" >LUNG_CANCER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5101_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d5101_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_d5101_row0_col1" class="data row0 col1" >69</td>
#       <td id="T_d5101_row0_col2" class="data row0 col2" >No</td>
#       <td id="T_d5101_row0_col3" class="data row0 col3" >Yes</td>
#       <td id="T_d5101_row0_col4" class="data row0 col4" >Yes</td>
#       <td id="T_d5101_row0_col5" class="data row0 col5" >No</td>
#       <td id="T_d5101_row0_col6" class="data row0 col6" >No</td>
#       <td id="T_d5101_row0_col7" class="data row0 col7" >Yes</td>
#       <td id="T_d5101_row0_col8" class="data row0 col8" >No</td>
#       <td id="T_d5101_row0_col9" class="data row0 col9" >Yes</td>
#       <td id="T_d5101_row0_col10" class="data row0 col10" >Yes</td>
#       <td id="T_d5101_row0_col11" class="data row0 col11" >Yes</td>
#       <td id="T_d5101_row0_col12" class="data row0 col12" >Yes</td>
#       <td id="T_d5101_row0_col13" class="data row0 col13" >Yes</td>
#       <td id="T_d5101_row0_col14" class="data row0 col14" >Yes</td>
#       <td id="T_d5101_row0_col15" class="data row0 col15" >YES</td>
#     </tr>
#     <tr>
#       <th id="T_d5101_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d5101_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_d5101_row1_col1" class="data row1 col1" >74</td>
#       <td id="T_d5101_row1_col2" class="data row1 col2" >Yes</td>
#       <td id="T_d5101_row1_col3" class="data row1 col3" >No</td>
#       <td id="T_d5101_row1_col4" class="data row1 col4" >No</td>
#       <td id="T_d5101_row1_col5" class="data row1 col5" >No</td>
#       <td id="T_d5101_row1_col6" class="data row1 col6" >Yes</td>
#       <td id="T_d5101_row1_col7" class="data row1 col7" >Yes</td>
#       <td id="T_d5101_row1_col8" class="data row1 col8" >Yes</td>
#       <td id="T_d5101_row1_col9" class="data row1 col9" >No</td>
#       <td id="T_d5101_row1_col10" class="data row1 col10" >No</td>
#       <td id="T_d5101_row1_col11" class="data row1 col11" >No</td>
#       <td id="T_d5101_row1_col12" class="data row1 col12" >Yes</td>
#       <td id="T_d5101_row1_col13" class="data row1 col13" >Yes</td>
#       <td id="T_d5101_row1_col14" class="data row1 col14" >Yes</td>
#       <td id="T_d5101_row1_col15" class="data row1 col15" >YES</td>
#     </tr>
#     <tr>
#       <th id="T_d5101_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d5101_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_d5101_row2_col1" class="data row2 col1" >59</td>
#       <td id="T_d5101_row2_col2" class="data row2 col2" >No</td>
#       <td id="T_d5101_row2_col3" class="data row2 col3" >No</td>
#       <td id="T_d5101_row2_col4" class="data row2 col4" >No</td>
#       <td id="T_d5101_row2_col5" class="data row2 col5" >Yes</td>
#       <td id="T_d5101_row2_col6" class="data row2 col6" >No</td>
#       <td id="T_d5101_row2_col7" class="data row2 col7" >Yes</td>
#       <td id="T_d5101_row2_col8" class="data row2 col8" >No</td>
#       <td id="T_d5101_row2_col9" class="data row2 col9" >Yes</td>
#       <td id="T_d5101_row2_col10" class="data row2 col10" >No</td>
#       <td id="T_d5101_row2_col11" class="data row2 col11" >Yes</td>
#       <td id="T_d5101_row2_col12" class="data row2 col12" >Yes</td>
#       <td id="T_d5101_row2_col13" class="data row2 col13" >No</td>
#       <td id="T_d5101_row2_col14" class="data row2 col14" >Yes</td>
#       <td id="T_d5101_row2_col15" class="data row2 col15" >NO</td>
#     </tr>
#     <tr>
#       <th id="T_d5101_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d5101_row3_col0" class="data row3 col0" >Male</td>
#       <td id="T_d5101_row3_col1" class="data row3 col1" >63</td>
#       <td id="T_d5101_row3_col2" class="data row3 col2" >Yes</td>
#       <td id="T_d5101_row3_col3" class="data row3 col3" >Yes</td>
#       <td id="T_d5101_row3_col4" class="data row3 col4" >Yes</td>
#       <td id="T_d5101_row3_col5" class="data row3 col5" >No</td>
#       <td id="T_d5101_row3_col6" class="data row3 col6" >No</td>
#       <td id="T_d5101_row3_col7" class="data row3 col7" >No</td>
#       <td id="T_d5101_row3_col8" class="data row3 col8" >No</td>
#       <td id="T_d5101_row3_col9" class="data row3 col9" >No</td>
#       <td id="T_d5101_row3_col10" class="data row3 col10" >Yes</td>
#       <td id="T_d5101_row3_col11" class="data row3 col11" >No</td>
#       <td id="T_d5101_row3_col12" class="data row3 col12" >No</td>
#       <td id="T_d5101_row3_col13" class="data row3 col13" >Yes</td>
#       <td id="T_d5101_row3_col14" class="data row3 col14" >Yes</td>
#       <td id="T_d5101_row3_col15" class="data row3 col15" >NO</td>
#     </tr>
#     <tr>
#       <th id="T_d5101_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d5101_row4_col0" class="data row4 col0" >Female</

# %%
sns.set_style("whitegrid")
sns.set_context("poster",font_scale = .7)

palette = ["#1d7874","#679289","#f4c095","#ee2e31","#ffb563","#918450","#f85e00","#a41623","#9a031e","#d6d6d6","#ffee32","#ffd100","#333533","#202020"]

# sns.palplot(sns.color_palette(palette))
# plt.show()

# %% [markdown]
# Vamos a crear un nuevo marco de datos que contenga solo datos de casos positivos

# %% [markdown]
# # Casos positivos de cancer de pulmón:

# %%
data_temp_pos = data_temp[data_temp["LUNG_CANCER"] == "YES"]
data_temp_pos.head().style.set_properties(**{"background-color": "#2a9d8f","color":"white","border": "1.5px  solid black"})
# Out:
# <style type="text/css">
# #T_1b7c1_row0_col0, #T_1b7c1_row0_col1, #T_1b7c1_row0_col2, #T_1b7c1_row0_col3, #T_1b7c1_row0_col4, #T_1b7c1_row0_col5, #T_1b7c1_row0_col6, #T_1b7c1_row0_col7, #T_1b7c1_row0_col8, #T_1b7c1_row0_col9, #T_1b7c1_row0_col10, #T_1b7c1_row0_col11, #T_1b7c1_row0_col12, #T_1b7c1_row0_col13, #T_1b7c1_row0_col14, #T_1b7c1_row0_col15, #T_1b7c1_row1_col0, #T_1b7c1_row1_col1, #T_1b7c1_row1_col2, #T_1b7c1_row1_col3, #T_1b7c1_row1_col4, #T_1b7c1_row1_col5, #T_1b7c1_row1_col6, #T_1b7c1_row1_col7, #T_1b7c1_row1_col8, #T_1b7c1_row1_col9, #T_1b7c1_row1_col10, #T_1b7c1_row1_col11, #T_1b7c1_row1_col12, #T_1b7c1_row1_col13, #T_1b7c1_row1_col14, #T_1b7c1_row1_col15, #T_1b7c1_row2_col0, #T_1b7c1_row2_col1, #T_1b7c1_row2_col2, #T_1b7c1_row2_col3, #T_1b7c1_row2_col4, #T_1b7c1_row2_col5, #T_1b7c1_row2_col6, #T_1b7c1_row2_col7, #T_1b7c1_row2_col8, #T_1b7c1_row2_col9, #T_1b7c1_row2_col10, #T_1b7c1_row2_col11, #T_1b7c1_row2_col12, #T_1b7c1_row2_col13, #T_1b7c1_row2_col14, #T_1b7c1_row2_col15, #T_1b7c1_row3_col0, #T_1b7c1_row3_col1, #T_1b7c1_row3_col2, #T_1b7c1_row3_col3, #T_1b7c1_row3_col4, #T_1b7c1_row3_col5, #T_1b7c1_row3_col6, #T_1b7c1_row3_col7, #T_1b7c1_row3_col8, #T_1b7c1_row3_col9, #T_1b7c1_row3_col10, #T_1b7c1_row3_col11, #T_1b7c1_row3_col12, #T_1b7c1_row3_col13, #T_1b7c1_row3_col14, #T_1b7c1_row3_col15, #T_1b7c1_row4_col0, #T_1b7c1_row4_col1, #T_1b7c1_row4_col2, #T_1b7c1_row4_col3, #T_1b7c1_row4_col4, #T_1b7c1_row4_col5, #T_1b7c1_row4_col6, #T_1b7c1_row4_col7, #T_1b7c1_row4_col8, #T_1b7c1_row4_col9, #T_1b7c1_row4_col10, #T_1b7c1_row4_col11, #T_1b7c1_row4_col12, #T_1b7c1_row4_col13, #T_1b7c1_row4_col14, #T_1b7c1_row4_col15 {
#   background-color: #2a9d8f;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_1b7c1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b7c1_level0_col0" class="col_heading level0 col0" >GENDER</th>
#       <th id="T_1b7c1_level0_col1" class="col_heading level0 col1" >AGE</th>
#       <th id="T_1b7c1_level0_col2" class="col_heading level0 col2" >SMOKING</th>
#       <th id="T_1b7c1_level0_col3" class="col_heading level0 col3" >YELLOW_FINGERS</th>
#       <th id="T_1b7c1_level0_col4" class="col_heading level0 col4" >ANXIETY</th>
#       <th id="T_1b7c1_level0_col5" class="col_heading level0 col5" >PEER_PRESSURE</th>
#       <th id="T_1b7c1_level0_col6" class="col_heading level0 col6" >CHRONIC DISEASE</th>
#       <th id="T_1b7c1_level0_col7" class="col_heading level0 col7" >FATIGUE </th>
#       <th id="T_1b7c1_level0_col8" class="col_heading level0 col8" >ALLERGY </th>
#       <th id="T_1b7c1_level0_col9" class="col_heading level0 col9" >WHEEZING</th>
#       <th id="T_1b7c1_level0_col10" class="col_heading level0 col10" >ALCOHOL CONSUMING</th>
#       <th id="T_1b7c1_level0_col11" class="col_heading level0 col11" >COUGHING</th>
#       <th id="T_1b7c1_level0_col12" class="col_heading level0 col12" >SHORTNESS OF BREATH</th>
#       <th id="T_1b7c1_level0_col13" class="col_heading level0 col13" >SWALLOWING DIFFICULTY</th>
#       <th id="T_1b7c1_level0_col14" class="col_heading level0 col14" >CHEST PAIN</th>
#       <th id="T_1b7c1_level0_col15" class="col_heading level0 col15" >LUNG_CANCER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b7c1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1b7c1_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_1b7c1_row0_col1" class="data row0 col1" >69</td>
#       <td id="T_1b7c1_row0_col2" class="data row0 col2" >No</td>
#       <td id="T_1b7c1_row0_col3" class="data row0 col3" >Yes</td>
#       <td id="T_1b7c1_row0_col4" class="data row0 col4" >Yes</td>
#       <td id="T_1b7c1_row0_col5" class="data row0 col5" >No</td>
#       <td id="T_1b7c1_row0_col6" class="data row0 col6" >No</td>
#       <td id="T_1b7c1_row0_col7" class="data row0 col7" >Yes</td>
#       <td id="T_1b7c1_row0_col8" class="data row0 col8" >No</td>
#       <td id="T_1b7c1_row0_col9" class="data row0 col9" >Yes</td>
#       <td id="T_1b7c1_row0_col10" class="data row0 col10" >Yes</td>
#       <td id="T_1b7c1_row0_col11" class="data row0 col11" >Yes</td>
#       <td id="T_1b7c1_row0_col12" class="data row0 col12" >Yes</td>
#       <td id="T_1b7c1_row0_col13" class="data row0 col13" >Yes</td>
#       <td id="T_1b7c1_row0_col14" class="data row0 col14" >Yes</td>
#       <td id="T_1b7c1_row0_col15" class="data row0 col15" >YES</td>
#     </tr>
#     <tr>
#       <th id="T_1b7c1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1b7c1_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_1b7c1_row1_col1" class="data row1 col1" >74</td>
#       <td id="T_1b7c1_row1_col2" class="data row1 col2" >Yes</td>
#       <td id="T_1b7c1_row1_col3" class="data row1 col3" >No</td>
#       <td id="T_1b7c1_row1_col4" class="data row1 col4" >No</td>
#       <td id="T_1b7c1_row1_col5" class="data row1 col5" >No</td>
#       <td id="T_1b7c1_row1_col6" class="data row1 col6" >Yes</td>
#       <td id="T_1b7c1_row1_col7" class="data row1 col7" >Yes</td>
#       <td id="T_1b7c1_row1_col8" class="data row1 col8" >Yes</td>
#       <td id="T_1b7c1_row1_col9" class="data row1 col9" >No</td>
#       <td id="T_1b7c1_row1_col10" class="data row1 col10" >No</td>
#       <td id="T_1b7c1_row1_col11" class="data row1 col11" >No</td>
#       <td id="T_1b7c1_row1_col12" class="data row1 col12" >Yes</td>
#       <td id="T_1b7c1_row1_col13" class="data row1 col13" >Yes</td>
#       <td id="T_1b7c1_row1_col14" class="data row1 col14" >Yes</td>
#       <td id="T_1b7c1_row1_col15" class="data row1 col15" >YES</td>
#     </tr>
#     <tr>
#       <th id="T_1b7c1_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_1b7c1_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_1b7c1_row2_col1" class="data row2 col1" >75</td>
#       <td id="T_1b7c1_row2_col2" class="data row2 col2" >No</td>
#       <td id="T_1b7c1_row2_col3" class="data row2 col3" >Yes</td>
#       <td id="T_1b7c1_row2_col4" class="data row2 col4" >No</td>
#       <td id="T_1b7c1_row2_col5" class="data row2 col5" >No</td>
#       <td id="T_1b7c1_row2_col6" class="data row2 col6" >Yes</td>
#       <td id="T_1b7c1_row2_col7" class="data row2 col7" >Yes</td>
#       <td id="T_1b7c1_row2_col8" class="data row2 col8" >Yes</td>
#       <td id="T_1b7c1_row2_col9" class="data row2 col9" >Yes</td>
#       <td id="T_1b7c1_row2_col10" class="data row2 col10" >No</td>
#       <td id="T_1b7c1_row2_col11" class="data row2 col11" >Yes</td>
#       <td id="T_1b7c1_row2_col12" class="data row2 col12" >Yes</td>
#       <td id="T_1b7c1_row2_col13" class="data row2 col13" >No</td>
#       <td id="T_1b7c1_row2_col14" class="data row2 col14" >No</td>
#       <td id="T_1b7c1_row2_col15" class="data row2 col15" >YES</td>
#     </tr>
#     <tr>
#       <th id="T_1b7c1_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T_1b7c1_row3_col0" class="data row3 col0" >Male</td>
#       <td id="T_1b7c1_row3_col1" class="data row3 col1" >52</td>
#       <td id="T_1b7c1_row3_col2" class="data row3 col2" >Yes</td>
#       <td id="T_1b7c1_row3_col3" class="data row3 col3" >No</td>
#       <td id="T_1b7c1_row3_col4" class="data row3 col4" >No</td>
#       <td id="T_1b7c1_row3_col5" class="data row3 col5" >No</td>
#       <td id="T_1b7c1_row3_col6" class="data row3 col6" >No</td>
#       <td id="T_1b7c1_row3_col7" class="data row3 col7" >Yes</td>
#       <td id="T_1b7c1_row3_col8" class="data row3 col8" >No</td>
#       <td id="T_1b7c1_row3_col9" class="data row3 col9" >Yes</td>
#       <td id="T_1b7c1_row3_col10" class="data row3 col10" >Yes</td>
#       <td id="T_1b7c1_row3_col11" class="data row3 col11" >Yes</td>
#       <td id="T_1b7c1_row3_col12" class="data row3 col12" >Yes</td>
#       <td id="T_1b7c1_row3_col13" class="data row3 col13" >No</td>
#       <td id="T_1b7c1_row3_col14" class="data row3 col14" >Yes</td>
#       <td id="T_1b7c1_row3_col15" class="data row3 col15" >YES</td>
#     </tr>
#     <tr>
#       <th id="T_1b7c1_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_1b7c1_row4_col0" class="data row4 col0" >Fema

# %% [markdown]
# # Distribución de la edad de los casos positivos:

# %%
_, axs = plt.subplots(2,1,figsize=(20,10),sharex=True,sharey=True)
plt.tight_layout(pad=4.0)

sns.histplot(data_temp_pos[data_temp_pos["GENDER"]=="Male"]["AGE"],color=palette[11],kde=True,ax=axs[0],bins=20,alpha=1,fill=True)
axs[0].lines[0].set_color(palette[12])
axs[0].set_title("\nPositive Male Cases Age Distribution\n",fontsize=20)
axs[0].set_xlabel("Age")
axs[0].set_ylabel("Quantity")

sns.histplot(data_temp_pos[data_temp_pos["GENDER"]=="Female"]["AGE"],color=palette[12],kde=True,ax=axs[1],bins=20,alpha=1,fill=True)
axs[1].lines[0].set_color(palette[11])
axs[1].set_title("\nPositive Female Cases Age Distribution\n",fontsize=20)
axs[1].set_xlabel("Age")
axs[1].set_ylabel("Quantity")

sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# # Hombres y mujeres en una misma figura:

# %%
plt.subplots(figsize=(20, 8))
p = sns.histplot(data=data_temp_pos,x="AGE",hue="GENDER",multiple="stack",palette=palette[11:13],kde=True,shrink=.99,bins=20,alpha=1,fill=True)
p.axes.lines[0].set_color(palette[11])
p.axes.lines[1].set_color(palette[12])
p.axes.set_title("\nPositive Cases Age Distribution\n",fontsize=20)
plt.ylabel("Count")
plt.xlabel("Age")

sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# # Género de los casos positivos:

# %%
plt.subplots(figsize=(12, 12))

labels = "Male","Female"
size = 0.5

wedges, texts, autotexts = plt.pie([len(data_temp_pos[data_temp_pos["GENDER"]=="Male"]["GENDER"]),
                                    len(data_temp_pos[data_temp_pos["GENDER"]=="Female"]["GENDER"])],
                                    explode = (0,0),
                                    textprops=dict(size= 25, color= "white"),
                                    autopct="%.2f%%", 
                                    pctdistance = 0.7,
                                    radius=.9, 
                                    colors = ["#0f4c5c","#FFC300"], 
                                    shadow = True,
                                    wedgeprops=dict(width = size, edgecolor = "white", 
                                    linewidth = 5),
                                    startangle = 0)

plt.legend(wedges, labels, title="Category",loc="center left",bbox_to_anchor=(1, 0, 0.5, 1))
plt.title("\nPositive Cases' Gender Distribution",fontsize=20)
plt.show()

# %% [markdown]
# # Razones De Los Casos Positivos De Género:

# %%
_, axs = plt.subplots(1,2,figsize=(20,8),sharex=True,sharey=True)
plt.tight_layout(pad=4.0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="SMOKING",hue_order=["Yes","No"],ax=axs[0],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[0].set_title("\nEffect of Smoking\n",fontsize=20)
axs[0].set_xlabel("Gender")
axs[0].set_ylabel("Quantity")
for container in axs[0].containers:
    axs[0].bar_label(container,label_type="center",padding=2,size=25,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="ALCOHOL CONSUMING",hue_order=["Yes","No"],ax=axs[1],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[1].set_title("\nEffect of Alcohol Consuming\n",fontsize=20)
axs[1].set_xlabel("Gender")
axs[1].set_ylabel("Quantity")
for container in axs[1].containers:
    axs[1].bar_label(container,label_type="center",padding=2,size=25,color="white",rotation=0)

sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# # Síntomas de los géneros de casos positivos:

# %%
_, axs = plt.subplots(2,5,figsize=(20,14),sharex=False,sharey=True)
plt.tight_layout(pad=4.0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="YELLOW_FINGERS",hue_order=["Yes","No"],ax=axs[0,0],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[0,0].set_ylabel("Total")
axs[0,0].legend(title="Yellow Fingers",loc="upper right")
for container in axs[0,0].containers:
    axs[0,0].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="ANXIETY",hue_order=["Yes","No"],ax=axs[0,1],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[0,1].set_ylabel("Total")
axs[0,1].legend(title="Anxiety",loc="upper right")
for container in axs[0,1].containers:
    axs[0,1].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="CHRONIC DISEASE",hue_order=["Yes","No"],ax=axs[0,2],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[0,2].set_ylabel("Total")
axs[0,2].legend(title="Chronic Disease",loc="upper right")
for container in axs[0,2].containers:
    axs[0,2].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="CHEST PAIN",hue_order=["Yes","No"],ax=axs[0,3],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[0,3].set_ylabel("Total")
axs[0,3].legend(title="Chest Pain",loc="upper right")
for container in axs[0,3].containers:
    axs[0,3].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="FATIGUE ",hue_order=["Yes","No"],ax=axs[0,4],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[0,4].set_ylabel("Total")
axs[0,4].legend(title="Fatigue",loc="upper right")
for container in axs[0,4].containers:
    axs[0,4].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="WHEEZING",hue_order=["Yes","No"],ax=axs[1,0],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[1,0].set_ylabel("Total")
axs[1,0].legend(title="Wheezing",loc="upper right")
for container in axs[1,0].containers:
    axs[1,0].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="COUGHING",hue_order=["Yes","No"],ax=axs[1,1],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[1,1].set_ylabel("Total")
axs[1,1].legend(title="Coughing",loc="upper right")
for container in axs[1,1].containers:
    axs[1,1].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="SHORTNESS OF BREATH",hue_order=["Yes","No"],ax=axs[1,2],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[1,2].set_ylabel("Total")
axs[1,2].legend(title="Short Breath",loc="upper right")
for container in axs[1,2].containers:
    axs[1,2].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)

sns.countplot(data=data_temp_pos,x="GENDER",hue="SWALLOWING DIFFICULTY",hue_order=["Yes","No"],ax=axs[1,3],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[1,3].set_ylabel("Total")
axs[1,3].legend(title="Swallowing Difficulty",loc="upper right")
for container in axs[1,3].containers:
    axs[1,3].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)    

sns.countplot(data=data_temp_pos,x="GENDER",hue="ALLERGY ",hue_order=["Yes","No"],ax=axs[1,4],palette=["#0f4c5c","#FFC300"],saturation=1)
axs[1,4].set_ylabel("Total")
axs[1,4].legend(title="Allergy",loc="upper right")
for container in axs[1,4].containers:
    axs[1,4].bar_label(container,label_type="center",padding=2,size=17,color="white",rotation=0)    

sns.despine(left=True, bottom=True)
plt.show()

# %% [markdown]
# # Matriz de correlación:

# %%
from sklearn.preprocessing import LabelEncoder
LabelEncoder = LabelEncoder()

data["GENDER"] = data["GENDER"].replace({"M" : "Male" , "F" : "Female"})
data["LUNG_CANCER"] = LabelEncoder.fit_transform(data["LUNG_CANCER"])

data = pd.get_dummies(data, columns= ["GENDER"])
data.rename(columns={"GENDER_Male" : "MALE", "GENDER_Female" : "FEMALE", "YELLOW_FINGERS" : "YELLOW FINGERS", "PEER_PRESSURE" : "PEER PRESSURE", "LUNG_CANCER" : "LUNG CANCER", "FATIGUE " : "FATIGUE", "ALLERGY " : "ALLERGY"}, inplace=True)
data = data[["AGE","MALE","FEMALE","ALCOHOL CONSUMING","CHEST PAIN","SHORTNESS OF BREATH","COUGHING","PEER PRESSURE","CHRONIC DISEASE","SWALLOWING DIFFICULTY","YELLOW FINGERS","ANXIETY","FATIGUE","ALLERGY","WHEEZING","LUNG CANCER"]]
data.head().style.set_properties(**{"background-color": "#2a9d8f","color":"white","border": "1.5px  solid black"})
# Out:
# <style type="text/css">
# #T_729c3_row0_col0, #T_729c3_row0_col1, #T_729c3_row0_col2, #T_729c3_row0_col3, #T_729c3_row0_col4, #T_729c3_row0_col5, #T_729c3_row0_col6, #T_729c3_row0_col7, #T_729c3_row0_col8, #T_729c3_row0_col9, #T_729c3_row0_col10, #T_729c3_row0_col11, #T_729c3_row0_col12, #T_729c3_row0_col13, #T_729c3_row0_col14, #T_729c3_row0_col15, #T_729c3_row1_col0, #T_729c3_row1_col1, #T_729c3_row1_col2, #T_729c3_row1_col3, #T_729c3_row1_col4, #T_729c3_row1_col5, #T_729c3_row1_col6, #T_729c3_row1_col7, #T_729c3_row1_col8, #T_729c3_row1_col9, #T_729c3_row1_col10, #T_729c3_row1_col11, #T_729c3_row1_col12, #T_729c3_row1_col13, #T_729c3_row1_col14, #T_729c3_row1_col15, #T_729c3_row2_col0, #T_729c3_row2_col1, #T_729c3_row2_col2, #T_729c3_row2_col3, #T_729c3_row2_col4, #T_729c3_row2_col5, #T_729c3_row2_col6, #T_729c3_row2_col7, #T_729c3_row2_col8, #T_729c3_row2_col9, #T_729c3_row2_col10, #T_729c3_row2_col11, #T_729c3_row2_col12, #T_729c3_row2_col13, #T_729c3_row2_col14, #T_729c3_row2_col15, #T_729c3_row3_col0, #T_729c3_row3_col1, #T_729c3_row3_col2, #T_729c3_row3_col3, #T_729c3_row3_col4, #T_729c3_row3_col5, #T_729c3_row3_col6, #T_729c3_row3_col7, #T_729c3_row3_col8, #T_729c3_row3_col9, #T_729c3_row3_col10, #T_729c3_row3_col11, #T_729c3_row3_col12, #T_729c3_row3_col13, #T_729c3_row3_col14, #T_729c3_row3_col15, #T_729c3_row4_col0, #T_729c3_row4_col1, #T_729c3_row4_col2, #T_729c3_row4_col3, #T_729c3_row4_col4, #T_729c3_row4_col5, #T_729c3_row4_col6, #T_729c3_row4_col7, #T_729c3_row4_col8, #T_729c3_row4_col9, #T_729c3_row4_col10, #T_729c3_row4_col11, #T_729c3_row4_col12, #T_729c3_row4_col13, #T_729c3_row4_col14, #T_729c3_row4_col15 {
#   background-color: #2a9d8f;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_729c3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_729c3_level0_col0" class="col_heading level0 col0" >AGE</th>
#       <th id="T_729c3_level0_col1" class="col_heading level0 col1" >MALE</th>
#       <th id="T_729c3_level0_col2" class="col_heading level0 col2" >FEMALE</th>
#       <th id="T_729c3_level0_col3" class="col_heading level0 col3" >ALCOHOL CONSUMING</th>
#       <th id="T_729c3_level0_col4" class="col_heading level0 col4" >CHEST PAIN</th>
#       <th id="T_729c3_level0_col5" class="col_heading level0 col5" >SHORTNESS OF BREATH</th>
#       <th id="T_729c3_level0_col6" class="col_heading level0 col6" >COUGHING</th>
#       <th id="T_729c3_level0_col7" class="col_heading level0 col7" >PEER PRESSURE</th>
#       <th id="T_729c3_level0_col8" class="col_heading level0 col8" >CHRONIC DISEASE</th>
#       <th id="T_729c3_level0_col9" class="col_heading level0 col9" >SWALLOWING DIFFICULTY</th>
#       <th id="T_729c3_level0_col10" class="col_heading level0 col10" >YELLOW FINGERS</th>
#       <th id="T_729c3_level0_col11" class="col_heading level0 col11" >ANXIETY</th>
#       <th id="T_729c3_level0_col12" class="col_heading level0 col12" >FATIGUE</th>
#       <th id="T_729c3_level0_col13" class="col_heading level0 col13" >ALLERGY</th>
#       <th id="T_729c3_level0_col14" class="col_heading level0 col14" >WHEEZING</th>
#       <th id="T_729c3_level0_col15" class="col_heading level0 col15" >LUNG CANCER</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_729c3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_729c3_row0_col0" class="data row0 col0" >69</td>
#       <td id="T_729c3_row0_col1" class="data row0 col1" >True</td>
#       <td id="T_729c3_row0_col2" class="data row0 col2" >False</td>
#       <td id="T_729c3_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_729c3_row0_col4" class="data row0 col4" >2</td>
#       <td id="T_729c3_row0_col5" class="data row0 col5" >2</td>
#       <td id="T_729c3_row0_col6" class="data row0 col6" >2</td>
#       <td id="T_729c3_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_729c3_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_729c3_row0_col9" class="data row0 col9" >2</td>
#       <td id="T_729c3_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_729c3_row0_col11" class="data row0 col11" >2</td>
#       <td id="T_729c3_row0_col12" class="data row0 col12" >2</td>
#       <td id="T_729c3_row0_col13" class="data row0 col13" >1</td>
#       <td id="T_729c3_row0_col14" class="data row0 col14" >2</td>
#       <td id="T_729c3_row0_col15" class="data row0 col15" >1</td>
#     </tr>
#     <tr>
#       <th id="T_729c3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_729c3_row1_col0" class="data row1 col0" >74</td>
#       <td id="T_729c3_row1_col1" class="data row1 col1" >True</td>
#       <td id="T_729c3_row1_col2" class="data row1 col2" >False</td>
#       <td id="T_729c3_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_729c3_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_729c3_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_729c3_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_729c3_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_729c3_row1_col8" class="data row1 col8" >2</td>
#       <td id="T_729c3_row1_col9" class="data row1 col9" >2</td>
#       <td id="T_729c3_row1_col10" class="data row1 col10" >1</td>
#       <td id="T_729c3_row1_col11" class="data row1 col11" >1</td>
#       <td id="T_729c3_row1_col12" class="data row1 col12" >2</td>
#       <td id="T_729c3_row1_col13" class="data row1 col13" >2</td>
#       <td id="T_729c3_row1_col14" class="data row1 col14" >1</td>
#       <td id="T_729c3_row1_col15" class="data row1 col15" >1</td>
#     </tr>
#     <tr>
#       <th id="T_729c3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_729c3_row2_col0" class="data row2 col0" >59</td>
#       <td id="T_729c3_row2_col1" class="data row2 col1" >False</td>
#       <td id="T_729c3_row2_col2" class="data row2 col2" >True</td>
#       <td id="T_729c3_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_729c3_row2_col4" class="data row2 col4" >2</td>
#       <td id="T_729c3_row2_col5" class="data row2 col5" >2</td>
#       <td id="T_729c3_row2_col6" class="data row2 col6" >2</td>
#       <td id="T_729c3_row2_col7" class="data row2 col7" >2</td>
#       <td id="T_729c3_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_729c3_row2_col9" class="data row2 col9" >1</td>
#       <td id="T_729c3_row2_col10" class="data row2 col10" >1</td>
#       <td id="T_729c3_row2_col11" class="data row2 col11" >1</td>
#       <td id="T_729c3_row2_col12" class="data row2 col12" >2</td>
#       <td id="T_729c3_row2_col13" class="data row2 col13" >1</td>
#       <td id="T_729c3_row2_col14" class="data row2 col14" >2</td>
#       <td id="T_729c3_row2_col15" class="data row2 col15" >0</td>
#     </tr>
#     <tr>
#       <th id="T_729c3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_729c3_row3_col0" class="data row3 col0" >63</td>
#       <td id="T_729c3_row3_col1" class="data row3 col1" >True</td>
#       <td id="T_729c3_row3_col2" class="data row3 col2" >False</td>
#       <td id="T_729c3_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_729c3_row3_col4" class="data row3 col4" >2</td>
#       <td id="T_729c3_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_729c3_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_729c3_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_729c3_row3_col8" class="data row3 col8" >1</td>
#       <td id="T_729c3_row3_col9" class="data row3 col9" >2</td>
#       <td id="T_729c3_row3_col10" class="data row3 col10" >2</td>
#       <td id="T_729c3_row3_col11" class="data row3 col11" >2</td>
#       <td id="T_729c3_row3_col12" class="data row3 col12" >1</td>
#       <td id="T_729c3_row3_col13" class="data row3 col13" >1</td>
#       <td id="T_729c3_row3_col14" class="data row3 col14" >1</td>
#       <td id="T_729c3_row3_col15" class="data row3 col15" >0</td>
#     </tr>
#     <tr>
#       <th id="T_729c3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_729c3_row4_col0" class="data row4 col0" >63</td>
#       <td id="T_729c3_row4_col1" class="data row4 col1" >False</td>
#       <td

# %%
plt.subplots(figsize =(16, 12))

p=sns.heatmap(data.corr(), cmap = palette, square=True, cbar_kws=dict(shrink =.99), 
            annot=True, vmin=-1, vmax=1, linewidths=0.1,linecolor='white',annot_kws=dict(fontsize =12))
p.axes.set_title("Pearson Correlation Of Features\n", fontsize=25)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Preprocesamiento para la clasificación:

# %%
x = data.drop("LUNG CANCER", axis = 1)
y = data["LUNG CANCER"]

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

scaler = StandardScaler()
x = scaler.fit_transform(x)
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

print(f"Shape of training data : {x_train.shape}, {y_train.shape}")
print(f"Shape of testing data : {x_test.shape}, {y_test.shape}")
# Out:
# Shape of training data : (220, 15), (220,)
# Shape of testing data : (56, 15), (56,)

# %% [markdown]
# # Modelo de Regresión Logística:

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report


lr = LogisticRegression()
lr.fit(x_train, y_train)
lr_pred = lr.predict(x_test)
lr_conf = confusion_matrix(y_test, lr_pred)
lr_report = classification_report(y_test, lr_pred)
lr_acc = round(accuracy_score(y_test, lr_pred)*100, ndigits = 2)
print(f"Confusion Matrix : \n\n{lr_conf}")
print(f"\nClassification Report : \n\n{lr_report}")
print(f"\nThe Accuracy of Logistic Regression is {lr_acc} %")
# Out:
# Confusion Matrix :
#
# [[ 5  7]
#  [ 0 44]]
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.42      0.59        12
#            1       0.86      1.00      0.93        44
#
#     accuracy                           0.88        56
#    macro avg       0.93      0.71      0.76        56
# weighted avg       0.89      0.88      0.85        56
#
#
# The Accuracy of Logistic Regression is 87.5 %

# %% [markdown]
# # Gaussian Naive Bayes Model:

# %%
from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB()
gnb.fit(x_train, y_train)
gnb_pred = gnb.predict(x_test)
gnb_conf = confusion_matrix(y_test, gnb_pred)
gnb_report = classification_report(y_test, gnb_pred)
gnb_acc = round(accuracy_score(y_test, gnb_pred)*100, ndigits = 2)
print(f"Confusion Matrix : \n\n{gnb_conf}")
print(f"\nClassification Report : \n\n{gnb_report}")
print(f"\nThe Accuracy of Gaussian Naive Bayes is {gnb_acc} %")
# Out:
# Confusion Matrix :
#
# [[ 8  4]
#  [ 1 43]]
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.67      0.76        12
#            1       0.91      0.98      0.95        44
#
#     accuracy                           0.91        56
#    macro avg       0.90      0.82      0.85        56
# weighted avg       0.91      0.91      0.91        56
#
#
# The Accuracy of Gaussian Naive Bayes is 91.07 %

# %% [markdown]
# # Bernoulli Naive Bayes Model:

# %%
from sklearn.naive_bayes import BernoulliNB

bnb = BernoulliNB()
bnb.fit(x_train, y_train)
bnb_pred = bnb.predict(x_test)
bnb_conf = confusion_matrix(y_test, bnb_pred)
bnb_report = classification_report(y_test, bnb_pred)
bnb_acc = round(accuracy_score(y_test, bnb_pred)*100, ndigits = 2)
print(f"Confusion Matrix : \n\n{bnb_conf}")
print(f"\nClassification Report : \n\n{bnb_report}")
print(f"\nThe Accuracy of Bernoulli Naive Bayes is {bnb_acc} %")
# Out:
# Confusion Matrix :
#
# [[ 8  4]
#  [ 1 43]]
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.67      0.76        12
#            1       0.91      0.98      0.95        44
#
#     accuracy                           0.91        56
#    macro avg       0.90      0.82      0.85        56
# weighted avg       0.91      0.91      0.91        56
#
#
# The Accuracy of Bernoulli Naive Bayes is 91.07 %

# %% [markdown]
# # Support Vector Machine Model:

# %%
from sklearn.svm import SVC

svm = SVC(C = 100, gamma = 0.002)
svm.fit(x_train, y_train)
svm_pred = svm.predict(x_test)
svm_conf = confusion_matrix(y_test, svm_pred)
svm_report = classification_report(y_test, svm_pred)
svm_acc = round(accuracy_score(y_test, svm_pred)*100, ndigits = 2)
print(f"Confusion Matrix : \n\n{svm_conf}")
print(f"\nClassification Report : \n\n{svm_report}")
print(f"\nThe Accuracy of Support Vector Machine is {svm_acc} %")
# Out:
# Confusion Matrix :
#
# [[ 4  8]
#  [ 0 44]]
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.33      0.50        12
#            1       0.85      1.00      0.92        44
#
#     accuracy                           0.86        56
#    macro avg       0.92      0.67      0.71        56
# weighted avg       0.88      0.86      0.83        56
#
#
# The Accuracy of Support Vector Machine is 85.71 %

# %% [markdown]
# # Random Forest Model:

# %%
from sklearn.ensemble import RandomForestClassifier

rfg = RandomForestClassifier(n_estimators = 100, random_state = 42) 
rfg.fit(x_train, y_train)
rfg_pred = rfg.predict(x_test)
rfg_conf = confusion_matrix(y_test, rfg_pred)
rfg_report = classification_report(y_test, rfg_pred)
rfg_acc = round(accuracy_score(y_test, rfg_pred)*100, ndigits = 2)
print(f"Confusion Matrix : \n\n{rfg_conf}")
print(f"\nClassification Report : \n\n{rfg_report}")
print(f"\nThe Accuracy of Random Forest Classifier is {rfg_acc} %")
# Out:
# Confusion Matrix :
#
# [[ 4  8]
#  [ 0 44]]
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.33      0.50        12
#            1       0.85      1.00      0.92        44
#
#     accuracy                           0.86        56
#    macro avg       0.92      0.67      0.71        56
# weighted avg       0.88      0.86      0.83        56
#
#
# The Accuracy of Random Forest Classifier is 85.71 %

# %% [markdown]
# # K Nearest Neighbors Model:

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=2)
knn.fit(x_train, y_train)
knn_pred = knn.predict(x_test)
knn_conf = confusion_matrix(y_test, knn_pred)
knn_report = classification_report(y_test, knn_pred)
knn_acc = round(accuracy_score(y_test, knn_pred)*100, ndigits = 2)
print(f"Confusion Matrix : \n\n{knn_conf}")
print(f"\nClassification Report : \n\n{knn_report}")
print(f"\nThe Accuracy of K Nearest Neighbors Classifier is {knn_acc} %")
# Out:
# Confusion Matrix :
#
# [[ 9  3]
#  [ 1 43]]
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.75      0.82        12
#            1       0.93      0.98      0.96        44
#
#     accuracy                           0.93        56
#    macro avg       0.92      0.86      0.89        56
# weighted avg       0.93      0.93      0.93        56
#
#
# The Accuracy of K Nearest Neighbors Classifier is 92.86 %

# %% [markdown]
# # Neural Network Architecture:

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam

regularization_parameter = 0.003

neural_model = Sequential([tf.keras.layers.Dense(units=32, input_dim=(x_train.shape[-1]), activation="relu", kernel_regularizer = regularizers.l1(regularization_parameter)),
                    tf.keras.layers.Dense(units=64, activation="relu", kernel_regularizer = regularizers.l1(regularization_parameter)),
                    tf.keras.layers.Dense(units=128, activation="relu", kernel_regularizer = regularizers.l1(regularization_parameter)),
                    tf.keras.layers.Dropout(0.3),
                    tf.keras.layers.Dense(units=16,activation="relu", kernel_regularizer = regularizers.l1(regularization_parameter)),
                    tf.keras.layers.Dense(units=1, activation="sigmoid")
                    ])

print(neural_model.summary())
# Out:
# /Users/amaliabeatrizvalientehinojosa/Documents/GitHub/Statistical-Analysis/my_env/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 16)             │         2,064 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,025 (50.88 KB)
#  Trainable params: 13,025 (50.88 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get("accuracy") == 1.0):
            print("\nAccuracy is 100% so canceling training!")
            self.model.stop_training = True

callbacks = myCallback()


neural_model.compile(optimizer = Adam(learning_rate = 0.001), 
                     loss = "binary_crossentropy", 
                     metrics = ["accuracy"])

history = neural_model.fit(x_train, y_train,
                           epochs = 150,
                           verbose = 1,
                           batch_size = 64,
                           validation_data = (x_test, y_test),
                           callbacks = [callbacks])
# Out:
# Epoch 1/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.8189 - loss: 4.3811 - val_accuracy: 0.7857 - val_loss: 4.2446
# Epoch 2/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8790 - loss: 4.1845 - val_accuracy: 0.7857 - val_loss: 4.0863
# Epoch 3/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8725 - loss: 4.0056 - val_accuracy: 0.7857 - val_loss: 3.9439
# Epoch 4/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8694 - loss: 3.8523 - val_accuracy: 0.7857 - val_loss: 3.8178
# Epoch 5/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8855 - loss: 3.6824 - val_accuracy: 0.7857 - val_loss: 3.7082
# Epoch 6/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8845 - loss: 3.5552 - val_accuracy: 0.7857 - val_loss: 3.6010
# Epoch 7/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8850 - loss: 3.4318 - val_accuracy: 0.7857 - val_loss: 3.4876
# Epoch 8/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8756 - loss: 3.3375 - val_accuracy: 0.7857 - val_loss: 3.3704
# Epoch 9/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8960 - loss: 3.1838 - val_accuracy: 0.7857 - val_loss: 3.2560
# Epoch 10/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8647 - loss: 3.1114 - val_accuracy: 0.7857 - val_loss: 3.1396
# Epoch 11/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9079 - loss: 2.9589 - val_accuracy: 0.7857 - val_loss: 3.0282
# Epoch 12/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8699 - loss: 2.8862 - val_accuracy: 0.7857 - val_loss: 2.9178
# Epoch 13/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8944 - loss: 2.7490 - val_accuracy: 0.7857 - val_loss: 2.8139
# Epoch 14/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8798 - loss: 2.6703 - val_accuracy: 0.7857 - val_loss: 2.7128
# Epoch 15/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8798 - loss: 2.5607 - val_accuracy: 0.7857 - val_loss: 2.6153
# Epoch 16/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8793 - loss: 2.4681 - val_accuracy: 0.7857 - val_loss: 2.5198
# Epoch 17/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8725 - loss: 2.3837 - val_accuracy: 0.7857 - val_loss: 2.4253
# Epoch 18/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8824 - loss: 2.2605 - val_accuracy: 0.7857 - val_loss: 2.3321
# Epoch 19/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8777 - loss: 2.1855 - val_accuracy: 0.7857 - val_loss: 2.2420
# Epoch 20/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8809 - loss: 2.1055 - val_accuracy: 0.7857 - val_loss: 2.1547
# Epoch 21/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8913 - loss: 1.9872 - val_accuracy: 0.7857 - val_loss: 2.0706
# Epoch 22/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8793 - loss: 1.9211 - val_accuracy: 0.7857 - val_loss: 1.9855
# Epoch 23/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8647 - loss: 1.8524 - val_accuracy: 0.7857 - val_loss: 1.9038
# Epoch 24/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8637 - loss: 1.7777 - val_accuracy: 0.7857 - val_loss: 1.8261
# Epoch 25/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8811 - loss: 1.6860 - val_accuracy: 0.7857 - val_loss: 1.7557
# Epoch 26/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8801 - loss: 1.6134 - val_accuracy: 0.7857 - val_loss: 1.6872
# Epoch 27/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8741 - loss: 1.5596 - val_accuracy: 0.7857 - val_loss: 1.6233
# Epoch 28/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8788 - loss: 1.4825 - val_accuracy: 0.7857 - val_loss: 1.5609
# Epoch 29/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8913 - loss: 1.4176 - val_accuracy: 0.7857 - val_loss: 1.4978
# Epoch 30/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8855 - loss: 1.3529 - val_accuracy: 0.7857 - val_loss: 1.4347
# Epoch 31/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8814 - loss: 1.2894 - val_accuracy: 0.7857 - val_loss: 1.3720
# Epoch 32/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8868 - loss: 1.2381 - val_accuracy: 0.7857 - val_loss: 1.3116
# Epoch 33/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8730 - loss: 1.1903 - val_accuracy: 0.7857 - val_loss: 1.2574
# Epoch 34/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9011 - loss: 1.1154 - val_accuracy: 0.7857 - val_loss: 1.2077
# Epoch 35/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9100 - loss: 1.0534 - val_accuracy: 0.7857 - val_loss: 1.1599
# Epoch 36/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8900 - loss: 1.0288 - val_accuracy: 0.7857 - val_loss: 1.1148
# Epoch 37/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8996 - loss: 0.9932 - val_accuracy: 0.7857 - val_loss: 1.0729
# Epoch 38/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9004 - loss: 0.9380 - val_accuracy: 0.7857 - val_loss: 1.0344
# Epoch 39/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8899 - loss: 0.9220 - val_accuracy: 0.7857 - val_loss: 0.9964
# Epoch 40/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8918 - loss: 0.8722 - val_accuracy: 0.7857 - val_loss: 0.9601
# Epoch 41/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9121 - loss: 0.8109 - val_accuracy: 0.7857 - val_loss: 0.9284
# Epoch 42/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9001 - loss: 0.8081 - val_accuracy: 0.7857 - val_loss: 0.8964
# Epoch 43/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8975 - loss: 0.7701 - val_accuracy: 0.7857 - val_loss: 0.8676
# Epoch 44/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9004 - loss: 0.7649 - val_accuracy: 0.7857 - val_loss: 0.8428
# Epoch 45/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9282 - loss: 0.7022 - val_accuracy: 0.7857 - val_loss: 0.8235
# Epoch 46/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9045 - loss: 0.7014 - val_accuracy: 0.7857 - val_loss: 0.7993
# Epoch 47/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9233 - loss: 0.6688 - val_accuracy: 0.7857 - val_loss: 0.7783
# Epoch 48/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9027 - loss: 0.6748 - val_accuracy: 0.7857 - val_loss: 0.7581
# Epoch 49/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9290 - loss: 0.6381 - val_accuracy: 0.7857 - val_loss: 0.7419
# Epoch 50/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9201 - loss: 0.6244 - val_accuracy: 0.7857 - val_loss: 0.7271
# Epoch 51/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9259 - loss: 0.6013 - val_accuracy: 0.7857 - val_loss: 0.7123
# Epoch 52/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9209 - loss: 0.5950 - val_accuracy: 0.7857 - val_loss: 0.6999
# Epoch 53/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9243 - loss: 0.5796 - val_accuracy: 0.7857 - val_loss: 0.6863
# Epoch 54/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9186 - loss: 0.5777 - val_accuracy: 0.7857 - val_loss: 0.6746
# Epoch 55/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9295 - loss: 0.5595 - val_accuracy: 0.7857 - val_loss: 0.6643
# Epoch 56/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9345 - loss: 0.5202 - val_accuracy: 0.8036 - val_loss: 0.6516
# Epoch 57/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9274 - loss: 0.5311 - val_accuracy: 0.8214 - val_loss: 0.6383
# Epoch 58/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9303 - loss: 0.5217 - val_accuracy: 0.8214 - val_loss: 0.6296
# Epoch 59/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9326 - loss: 0.5183 - val_accuracy: 0.8036 - val_loss: 0.6244
# Epoch 60/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9256 - loss: 0.5065 - val_accuracy: 0.8036 - val_loss: 0.6184
# Epoch 61/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9227 - loss: 0.5059 - val_accuracy: 0.8036 - val_loss: 0.6126
# Epoch 62/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9165 - loss: 0.4921 - val_accuracy: 0.8214 - val_loss: 0.6076
# Epoch 63/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9277 - loss: 0.4813 - val_accuracy: 0.8214 - val_loss: 0.5983
# Epoch 64/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9256 - loss: 0.4871 - val_accuracy: 0.8214 - val_loss: 0.5885
# Epoch 65/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9475 - loss: 0.4735 - val_accuracy: 0.8214 - val_loss: 0.5810
# Epoch 66/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9514 - loss: 0.4586 - val_accuracy: 0.8393 - val_loss: 0.5735
# Epoch 67/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9511 - loss: 0.4653 - val_accuracy: 0.8393 - val_loss: 0.5656
# Epoch 68/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9347 - loss: 0.4541 - val_accuracy: 0.8393 - val_loss: 0.5592
# Epoch 69/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9469 - loss: 0.4496 - val_accuracy: 0.8393 - val_loss: 0.5564
# Epoch 70/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9493 - loss: 0.4390 - val_accuracy: 0.8214 - val_loss: 0.5558
# Epoch 71/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9433 - loss: 0.4410 - val_accuracy: 0.8214 - val_loss: 0.5537
# Epoch 72/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9251 - loss: 0.4627 - val_accuracy: 0.8393 - val_loss: 0.5473
# Epoch 73/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9350 - loss: 0.4425 - val_accuracy: 0.8393 - val_loss: 0.5440
# Epoch 74/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9313 - loss: 0.4326 - val_accuracy: 0.8393 - val_loss: 0.5409
# Epoch 75/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9331 - loss: 0.4454 - val_accuracy: 0.8393 - val_loss: 0.5374
# Epoch 76/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9449 - loss: 0.4180 - val_accuracy: 0.8393 - val_loss: 0.5356
# Epoch 77/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9501 - loss: 0.4118 - val_accuracy: 0.8393 - val_loss: 0.5310
# Epoch 78/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9368 - loss: 0.4291 - val_accuracy: 0.8393 - val_loss: 0.5251
# Epoch 79/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9475 - loss: 0.4154 - val_accuracy: 0.8393 - val_loss: 0.5207
# Epoch 80/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9464 - loss: 0.4296 - val_accuracy: 0.8393 - val_loss: 0.5150
# Epoch 81/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9495 - loss: 0.4023 - val_accuracy: 0.8393 - val_loss: 0.5121
# Epoch 82/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9422 - loss: 0.4088 - val_accuracy: 0.8393 - val_loss: 0.5099
# Epoch 83/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9527 - loss: 0.4040 - val_accuracy: 0.8393 - val_loss: 0.5071
# Epoch 84/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9323 - loss: 0.4076 - val_accuracy: 0.8393 - val_loss: 0.5041
# Epoch 85/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9376 - loss: 0.4058 - val_accuracy: 0.8393 - val_loss: 0.5025
# Epoch 86/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9407 - loss: 0.4018 - val_accuracy: 0.8393 - val_loss: 0.4984
# Epoch 87/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9480 - loss: 0.3884 - val_accuracy: 0.8393 - val_loss: 0.4962
# Epoch 88/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9355 - loss: 0.4063 - val_accuracy: 0.8393 - val_loss: 0.4915
# Epoch 89/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9417 - loss: 0.3794 - val_accuracy: 0.8393 - val_loss: 0.4889
# Epoch 90/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9480 - loss: 0.3771 - val_accuracy: 0.8393 - val_loss: 0.4870
# Epoch 91/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9459 - loss: 0.3630 - val_accuracy: 0.8393 - val_loss: 0.4833
# Epoch 92/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9297 - loss: 0.3896 - val_accuracy: 0.8393 - val_loss: 0.4781
# Epoch 93/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9417 - loss: 0.3701 - val_accuracy: 0.8393 - val_loss: 0.4743
# Epoch 94/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9448 - loss: 0.3671 - val_accuracy: 0.8393 - val_loss: 0.4699
# Epoch 95/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9464 - loss: 0.3584 - val_accuracy: 0.8393 - val_loss: 0.4668
# Epoch 96/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9501 - loss: 0.3560 - val_accuracy: 0.8393 - val_loss: 0.4667
# Epoch 97/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9399 - loss: 0.3626 - val_accuracy: 0.8571 - val_loss: 0.4618
# Epoch 98/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9292 - loss: 0.3858 - val_accuracy: 0.8571 - val_loss: 0.4566
# Epoch 99/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9495 - loss: 0.3559 - val_accuracy: 0.8571 - val_loss: 0.4539
# Epoch 100/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9589 - loss: 0.3369 - val_accuracy: 0.8571 - val_loss: 0.4535
# Epoch 101/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9485 - loss: 0.3477 - val_accuracy: 0.8571 - val_loss: 0.4514
# Epoch 102/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9422 - loss: 0.3562 - val_accuracy: 0.8571 - val_loss: 0.4507
# Epoch 103/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9448 - loss: 0.3558 - val_accuracy: 0.8571 - val_loss: 0.4450
# Epoch 104/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9475 - loss: 0.3441 - val_accuracy: 0.8571 - val_loss: 0.4412
# Epoch 105/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9563 - loss: 0.3379 - val_accuracy: 0.8571 - val_loss: 0.4389
# Epoch 106/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9448 - loss: 0.3406 - val_accuracy: 0.8571 - val_loss: 0.4360
# Epoch 107/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9534 - loss: 0.3383 - val_accuracy: 0.8571 - val_loss: 0.4397
# Epoch 108/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9412 - loss: 0.3317 - val_accuracy: 0.8571 - val_loss: 0.4372
# Epoch 109/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9402 - loss: 0.3328 - val_accuracy: 0.8571 - val_loss: 0.4331
# Epoch 110/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9550 - loss: 0.3289 - val_accuracy: 0.8571 - val_loss: 0.4289
# Epoch 111/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9610 - loss: 0.3339 - val_accuracy: 0.8929 - val_loss: 0.4243
# Epoch 112/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9542 - loss: 0.3454 - val_accuracy: 0.8929 - val_loss: 0.4215
# Epoch 113/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9584 - loss: 0.3323 - val_accuracy: 0.8750 - val_loss: 0.4224
# Epoch 114/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9542 - loss: 0.3372 - val_accuracy: 0.8571 - val_loss: 0.4232
# Epoch 115/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9589 - loss: 0.3115 - val_accuracy: 0.8571 - val_loss: 0.4243
# Epoch 116/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9456 - loss: 0.3219 - val_accuracy: 0.8571 - val_loss: 0.4244
# Epoch 117/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9521 - loss: 0.3232 - val_accuracy: 0.8571 - val_loss: 0.4194
# Epoch 118/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9550 - loss: 0.3122 - val_accuracy: 0.8571 - val_loss: 0.4175
# Epoch 119/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9605 - loss: 0.3175 - val_accuracy: 0.8571 - val_loss: 0.4143
# Epoch 120/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9558 - loss: 0.3108 - val_accuracy: 0.9107 - val_loss: 0.4110
# Epoch 121/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9454 - loss: 0.3185 - val_accuracy: 0.9107 - val_loss: 0.4111
# Epoch 122/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9558 - loss: 0.3164 - val_accuracy: 0.8571 - val_loss: 0.4144
# Epoch 123/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9628 - loss: 0.3008 - val_accuracy: 0.8571 - val_loss: 0.4151
# Epoch 124/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9482 - loss: 0.3151 - val_accuracy: 0.8571 - val_loss: 0.4136
# Epoch 125/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9485 - loss: 0.3153 - val_accuracy: 0.8750 - val_loss: 0.4111
# Epoch 126/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9477 - loss: 0.3209 - val_accuracy: 0.8929 - val_loss: 0.4079
# Epoch 127/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9571 - loss: 0.3059 - val_accuracy: 0.8750 - val_loss: 0.4085
# Epoch 128/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9612 - loss: 0.3096 - val_accuracy: 0.8571 - val_loss: 0.4092
# Epoch 129/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9610 - loss: 0.2935 - val_accuracy: 0.8571 - val_loss: 0.4083
# Epoch 130/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9625 - loss: 0.2903 - val_accuracy: 0.8929 - val_loss: 0.4027
# Epoch 131/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9623 - loss: 0.2888 - val_accuracy: 0.8929 - val_loss: 0.3990
# Epoch 132/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9568 - loss: 0.2959 - val_accuracy: 0.8929 - val_loss: 0.3961
# Epoch 133/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9677 - loss: 0.2821 - val_accuracy: 0.9107 - val_loss: 0.3950
# Epoch 134/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9628 - loss: 0.3006 - val_accuracy: 0.9107 - val_loss: 0.3948
# Epoch 135/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9539 - loss: 0.2845 - val_accuracy: 0.9107 - val_loss: 0.3935
# Epoch 136/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9664 - loss: 0.2657 - val_accuracy: 0.9107 - val_loss: 0.3940
# Epoch 137/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9568 - loss: 0.2874 - val_accuracy: 0.9107 - val_loss: 0.3953
# Epoch 138/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9417 - loss: 0.2941 - val_accuracy: 0.9107 - val_loss: 0.3917
# Epoch 139/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9607 - loss: 0.2854 - val_accuracy: 0.9107 - val_loss: 0.3899
# Epoch 140/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9667 - loss: 0.2939 - val_accuracy: 0.9107 - val_loss: 0.3890
# Epoch 141/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9607 - loss: 0.2762 - val_accuracy: 0.9107 - val_loss: 0.3909
# Epoch 142/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9566 - loss: 0.2864 - val_accuracy: 0.9107 - val_loss: 0.3897
# Epoch 143/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9584 - loss: 0.2872 - val_accuracy: 0.9107 - val_loss: 0.3875
# Epoch 144/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9503 - loss: 0.2920 - val_accuracy: 0.9107 - val_loss: 0.3848
# Epoch 145/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9612 - loss: 0.2894 - val_accuracy: 0.9107 - val_loss: 0.3837
# Epoch 146/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9638 - loss: 0.2736 - val_accuracy: 0.9107 - val_loss: 0.3824
# Epoch 147/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9670 - loss: 0.2745 - val_accuracy: 0.9107 - val_loss: 0.3812
# Epoch 148/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9537 - loss: 0.2873 - val_accuracy: 0.9107 - val_loss: 0.3790
# Epoch 149/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9464 - loss: 0.2907 - val_accuracy: 0.9107 - val_loss: 0.3760
# Epoch 150/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9628 - loss: 0.2771 - val_accuracy: 0.9107 - val_loss: 0.3760

# %%
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]

epochs = range(len(acc)) # number of epochs

plt.figure(figsize=(20, 12))
plt.subplot(2,1,1)
plt.plot(epochs, acc, "yellow", label= "Training Accuracy")
plt.plot(epochs, val_acc, "black", label= "Validation Accuracy")
plt.title("Training and validation accuracy")
plt.legend()

plt.subplot(2,1,2)
plt.plot(epochs, loss, "yellow", label= "Training Loss")
plt.plot(epochs, val_loss, "black", label= "Validation Loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# # Pruebas de hipótesis:

# %%
# data_temp_pos
# data
# Convertir variables categóricas a numéricas

data_ = pd.read_csv(file_path)
data_pos = data_[data_["LUNG_CANCER"] == "YES"]
print(data_.columns)  # Ver las columnas de 'data'
print(data_pos.columns)  # Ver las columnas de 'data_temp_pos'

data_["LUNG_CANCER"] = data_["LUNG_CANCER"].map({"YES": 1, "NO": 0})
data_["SMOKING"] = data_["SMOKING"].map({1: 0, 2: 1})

data_pos.loc[:, "LUNG_CANCER"] = data_pos["LUNG_CANCER"].map({"YES": 1, "NO": 0})
data_pos.loc[:, "SMOKING"] = data_pos["SMOKING"].map({1: 0, 2: 1})
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER'],
#       dtype='object')
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %% [markdown]
# **Prueba t de Student**: Diferencia de edad entre pacientes con y sin cáncer de pulmón.
#
# Esta prueba nos ayuda a determinar si la edad promedio difiere significativamente entre pacientes con y sin cáncer, lo que podría indicar que la edad es un factor de riesgo importante.
#
# **Hipótesis Nula**: No hay diferencia significativa en la edad promedio entre pacientes con y sin cáncer de pulmón.
# **Hipótesis Alternativa**: Existe una diferencia significativa en la edad promedio entre ambos grupos.

# %%
# 1. Prueba t de Student: Diferencia de edad entre pacientes con y sin cáncer de pulmón
age_cancer = data_[data_['LUNG_CANCER'] == 1]['AGE']
age_no_cancer = data_[data_['LUNG_CANCER'] == 0]['AGE']
t_stat, p_value_ttest = stats.ttest_ind(age_cancer, age_no_cancer, equal_var=False)
print(f'Prueba t: t-stat={t_stat}, p-valor={p_value_ttest}')
# Out:
# Prueba t: t-stat=1.366213567102624, p-valor=0.17853961810400154

# %% [markdown]
# Como podemos ver, el p-valor dio como resultado un valor mayor que 0.05, por tanto, podemos decir que no hay suficiente evidencia en este conjunto de datos para afirmar que la edad difiere significativamente entre las perssonas que tienen cancer de pulmón y las que no.

# %% [markdown]
# # Prueba de Chi-cuadrado: Asociación entre síntomas y cáncer de pulmón.
# Esta prueba permite evaluar si síntomas como tos, dificultad para respirar y fatiga están relacionados con la presencia de cáncer de pulmón, lo que ayuda en el diagnóstico temprano.

# %%
# 2. Prueba de Chi-cuadrado: Asociación entre síntomas y cáncer de pulmón
symptoms = ['COUGHING', 'SHORTNESS OF BREATH', 'FATIGUE ']
p_values_symptoms = {}
for symptom in symptoms:
    contingency = pd.crosstab(data_[symptom], data_['LUNG_CANCER'])
    chi2, p_value, _, _ = stats.chi2_contingency(contingency)
    p_values_symptoms[symptom] = p_value
    print(f'Chi-cuadrado para {symptom}: chi2={chi2}, p-valor={p_value}')
# Out:
# Chi-cuadrado para COUGHING: chi2=17.606121643361654, p-valor=2.717122985492556e-05
# Chi-cuadrado para SHORTNESS OF BREATH: chi2=0.7906043281043282, p-valor=0.3739174525027509
# Chi-cuadrado para FATIGUE : chi2=6.081100453795381, p-valor=0.013663563031648581

# %% [markdown]
# Los resultados nos llevan a la conclusión de que ni la tos ni la falta de aire  son fuertes indicadores de cancer de pulmón, mientas que la fatiga sí lo es.

# %% [markdown]
# # Prueba Z para diferencia de proporciones: Fumar y cáncer de pulmón.
# Esta prueba de hipótesis analiza si la proporción de fumadores es significativamente diferente entre quienes tienen cáncer y quienes no, ayudando a confirmar si el tabaquismo es un factor de riesgo.
#
# **Hipótesis Nula** : No hay diferencia en la proporción de fumadores entre pacientes con y sin cáncer de pulmón.
# **Hipótesis Alternativa**: Existe una diferencia significativa en la proporción de fumadores entre los grupos.

# %%
# 3. Prueba Z para diferencia de proporciones: Fumar y cáncer de pulmón
count = np.array([data_[data_['LUNG_CANCER'] == 1]['SMOKING'].sum(), data_[data_['LUNG_CANCER'] == 0]['SMOKING'].sum()])
nobs = np.array([data_[data_['LUNG_CANCER'] == 1]['SMOKING'].count(), data_[data_['LUNG_CANCER'] == 0]['SMOKING'].count()])
z_stat, p_value_ztest = proportions_ztest(count, nobs)
print(f'Prueba Z (fumar vs. cáncer de pulmón): z-stat={z_stat}, p-valor={p_value_ztest}')
# Out:
# Prueba Z (fumar vs. cáncer de pulmón): z-stat=1.0226914845280688, p-valor=0.30645373888225

# %% [markdown]
# Los resultados arrojan que no hay suficiente evidencia para afirmar que fumar está significativamente asociado al cancer de pulmón.

# %% [markdown]
# #  Prueba de Chi-cuadrado: Asociación entre consumo de alcohol y cáncer de pulmón.
# Parecida a la anterior, esta prueba evalúa si existe una asociación entre el consumo de alcohol y el cáncer de pulmón, lo que podría aportar información sobre hábitos de vida y su impacto en la enfermedad.
# **Hipótesis Nula**: No hay relación entre el consumo de alcohol y el cáncer de pulmón.
# **Hipótesis Alternativa**: Existe una asociación significativa entre el consumo de alcohol y el cáncer de pulmón.

# %%
# 4. Prueba de Chi-cuadrado: Consumo de alcohol y cáncer de pulmón
contingency_alcohol = pd.crosstab(data_['ALCOHOL CONSUMING'], data_['LUNG_CANCER'])
chi2_alcohol, p_value_alcohol, _, _ = stats.chi2_contingency(contingency_alcohol)
print(f'Chi-cuadrado para consumo de alcohol y cáncer de pulmón: chi2={chi2_alcohol}, p-valor={p_value_alcohol}')
# Out:
# Chi-cuadrado para consumo de alcohol y cáncer de pulmón: chi2=24.00540608990681, p-valor=9.606558962465625e-07

# %% [markdown]
# Los resultados nos dicen que no hay suficiente evidencia para demostrar que el consumo de alcohol esta relacionado con el cancer de pulmón.

# %% [markdown]
# # Regresión logística: Factores de riesgo del cáncer de pulmón.
#
# Esta prueba nos permite analizar múltiples variables simultáneamente para identificar cuáles tienen mayor impacto en el desarrollo del cáncer, ayudando en la identificación de factores de riesgo clave.
# **Hipótesis Nula**: Ninguna de las variables independientes (edad, fumar, alcohol, síntomas) tiene un impacto significativo en la probabilidad de tener cáncer de pulmón.
# **Hipótesis Alternativa**: Al menos una de las variables independientes influye significativamente en la probabilidad de tener cáncer de pulmón.

# %%
# 5. Regresión logística para evaluar factores de riesgo en cáncer de pulmón
independent_vars = ['AGE', 'SMOKING', 'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH', 'FATIGUE ']
X = data_[independent_vars]
X = sm.add_constant(X)
Y = data_['LUNG_CANCER']
logit_model = sm.Logit(Y, X)
result = logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.284456
#          Iterations 8
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:            LUNG_CANCER   No. Observations:                  309
# Model:                          Logit   Df Residuals:                      302
# Method:                           MLE   Df Model:                            6
# Date:                Sun, 09 Feb 2025   Pseudo R-squ.:                  0.2497
# Time:                        16:47:36   Log-Likelihood:                -87.897
# converged:                       True   LL-Null:                       -117.15
# Covariance Type:            nonrobust   LLR p-value:                 9.051e-11
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  -7.3241      1.933     -3.789      0.000     -11.113      -3.535
# AGE                     0.0173      0.022      0.771      0.441      -0.027       0.061
# SMOKING                 0.9619      0.425      2.263      0.024       0.129       1.795
# ALCOHOL CONSUMING       2.3563      0.498      4.728      0.000       1.380       3.333
# COUGHING                1.5755      0.464      3.395      0.001       0.666       2.485
# SHORTNESS OF BREATH    -0.2034      0.470     -0.433      0.665      -1.124       0.717
# FATIGUE                 1.5967      0.469      3.407      0.001       0.678       2.515
# =======================================================================================

# %% [markdown]
# # Prueba de Chi-cuadrado: Comparación de síntomas entre hombres y mujeres.
# Esta prueba analiza si ciertos síntomas son más frecuentes en un género específico, lo que podría mejorar la personalización de estrategias de detección y tratamiento.
# **Hipótesis Nula** : No hay diferencias en la presencia de síntomas entre hombres y mujeres.
# **Hipótesis Alternativa**: Hay diferencias significativas en los síntomas entre hombres y mujeres.

# %%
# 6. Prueba de Chi-cuadrado: Comparación de síntomas entre hombres y mujeres
gender_symptoms = ['COUGHING', 'WHEEZING', 'FATIGUE ']
p_values_gender = {}
for symptom in gender_symptoms:
    contingency = pd.crosstab(data_['GENDER'], data_[symptom])
    chi2, p_value, _, _ = stats.chi2_contingency(contingency)
    p_values_gender[symptom] = p_value
    print(f'Chi-cuadrado para {symptom} entre géneros: chi2={chi2}, p-valor={p_value}')
# Out:
# Chi-cuadrado para COUGHING entre géneros: chi2=4.963429198495046, p-valor=0.02588881904179743
# Chi-cuadrado para WHEEZING entre géneros: chi2=5.60524518116532, p-valor=0.017906789057283674
# Chi-cuadrado para FATIGUE  entre géneros: chi2=1.8155842235028048, p-valor=0.17783979904693
